# %% [markdown]
# importing important module

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten,Dropout
from keras.preprocessing.image import ImageDataGenerator

# %%
os.getcwd()
# Out:
# '/home/harshmeetsingh/Downloads/archive'

# %% [markdown]
# Create the data

# %%
#The dataset has folders from 0–42 i.e. 43 classes
X = []
Y = []
total_class = 43
cur_directory = os.getcwd()
for index in range(total_class):
    path = os.path.join(cur_directory,"train",str(index))
    print(path)
    images = os.listdir(path)#iterating on all the images of the index folder  
    for img in images:
        
        try:
            image = Image.open(path + '/'+ img)
            image = image.resize((30,30))
            image = np.array(image)      
            X.append(image)
            Y.append(index)
        except:
            print("Error loading image")
X = np.array(X)
Y = np.array(Y)
print(X.shape, Y.shape)
# Out:
# /home/harshmeetsingh/Downloads/archive/train/0
# /home/harshmeetsingh/Downloads/archive/train/1
# /home/harshmeetsingh/Downloads/archive/train/2
# /home/harshmeetsingh/Downloads/archive/train/3
# /home/harshmeetsingh/Downloads/archive/train/4
# /home/harshmeetsingh/Downloads/archive/train/5
# /home/harshmeetsingh/Downloads/archive/train/6
# /home/harshmeetsingh/Downloads/archive/train/7
# /home/harshmeetsingh/Downloads/archive/train/8
# /home/harshmeetsingh/Downloads/archive/train/9
# /home/harshmeetsingh/Downloads/archive/train/10
# /home/harshmeetsingh/Downloads/archive/train/11
# /home/harshmeetsingh/Downloads/archive/train/12
# /home/harshmeetsingh/Downloads/archive/train/13
# /home/harshmeetsingh/Downloads/archive/train/14
# /home/harshmeetsingh/Downloads/archive/train/15
# /home/harshmeetsingh/Downloads/archive/train/16
# /home/harshmeetsingh/Downloads/archive/train/17
# /home/harshmeetsingh/Downloads/archive/train/18
# /home/harshmeetsingh/Downloads/archive/train/19
# /home/harshmeetsingh/Downloads/archive/train/20
# /home/harshmeetsingh/Downloads/archive/train/21
# /home/harshmeetsingh/Downloads/archive/train/22
# /home/harshmeetsingh/Downloads/archive/train/23
# /home/harshmeetsingh/Downloads/archive/train/24
# /home/harshmeetsingh/Downloads/archive/train/25
# /home/harshmeetsingh/Downloads/archive/train/26
# /home/harshmeetsingh/Downloads/archive/train/27
# /home/harshmeetsingh/Downloads/archive/train/28
# /home/harshmeetsingh/Downloads/archive/train/29
# /home/harshmeetsingh/Downloads/archive/train/30
# /home/harshmeetsingh/Downloads/archive/train/31
# /home/harshmeetsingh/Downloads/archive/train/32
# /home/harshmeetsingh/Downloads/archive/train/33
# /home/harshmeetsingh/Downloads/archive/train/34
# /home/harshmeetsingh/Downloads/archive/train/35
# /home/harshmeetsingh/Downloads/archive/train/36
# /home/harshmeetsingh/Downloads/archive/train/37
# /home/harshmeetsingh/Downloads/archive/train/38
# /home/harshmeetsingh/Downloads/archive/train/39
# /home/harshmeetsingh/Downloads/archive/train/40
# /home/harshmeetsingh/Downloads/archive/train/41
# /home/harshmeetsingh/Downloads/archive/train/42
# (39209, 30, 30, 3) (39209,)

# %% [markdown]
# Making data ready for training

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print("Shape of x_train: ", x_train.shape, " and y_train:",y_train.shape)
print("Shape of x_test: ", x_test.shape, " and y_test:",y_test.shape)#one hot encoding the labels
# Out:
# Shape of x_train:  (31367, 30, 30, 3)  and y_train: (31367,)
# Shape of x_test:  (7842, 30, 30, 3)  and y_test: (7842,)

# %%
datagen = ImageDataGenerator(
        rotation_range=10, # rotation
        width_shift_range=0.2, # horizontal shift
        height_shift_range=0.2, # vertical shift
        zoom_range=0.2, # zoom
        horizontal_flip=True, # horizontal flip
        brightness_range=[0.2,1.2])
dataGen.fit(X_train)
batches= dataGen.flow(X_train,y_train,batch_size=64)  # REQUESTING DATA GENRATOR TO GENERATE IMAGES  BATCH SIZE = NO. OF IMAGES CREAED EACH TIME ITS CALLED
X_batch,y_batch = next(batches)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ad4e8bb4a624> in <module>
# ----> 1 datagen = ImageDataGenerator(
#       2         rotation_range=10, # rotation
#       3         width_shift_range=0.2, # horizontal shift
#       4         height_shift_range=0.2, # vertical shift
#       5         zoom_range=0.2, # zoom
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
X_batch

# %%
y_train = tf.keras.utils.to_categorical(y_train, 43)
y_test = tf.keras.utils.to_categorical(y_test, 43)
print(y_test)
# Out:
# (30, 30, 3)

# %%
x_train.shape[1:]

# %% [markdown]
# The model architecture

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=(30, 30, 3)))

model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))

model.add(Flatten())
model.add(Dense(576, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(156, activation='relu'))
model.add(Dropout(rate=0.5))

model.add(Dense(43, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        2432
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 22, 22, 32)        25632
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 9, 9, 64)          18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               147712
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 242,251
# Trainable params: 242,251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training and saving the model

# %%
epochs = 15
history = model.fit(x_train, y_train, batch_size=64, epochs=epochs,validation_data=(x_test, y_test))
model.save('traffic_recognition.h5')
# Out:
# Epoch 1/15
# 491/491 [==============================] - 100s 199ms/step - loss: 2.7419 - accuracy: 0.3669 - val_loss: 0.7962 - val_accuracy: 0.8202
# Epoch 2/15
# 491/491 [==============================] - 82s 166ms/step - loss: 0.8753 - accuracy: 0.7461 - val_loss: 0.2522 - val_accuracy: 0.9343
# Epoch 3/15
# 491/491 [==============================] - 81s 164ms/step - loss: 0.4985 - accuracy: 0.8501 - val_loss: 0.1355 - val_accuracy: 0.9637
# Epoch 4/15
# 491/491 [==============================] - 81s 164ms/step - loss: 0.3539 - accuracy: 0.8965 - val_loss: 0.0893 - val_accuracy: 0.9745
# Epoch 5/15
# 491/491 [==============================] - 81s 164ms/step - loss: 0.2721 - accuracy: 0.9200 - val_loss: 0.0759 - val_accuracy: 0.9790
# Epoch 6/15
# 491/491 [==============================] - 81s 164ms/step - loss: 0.2396 - accuracy: 0.9319 - val_loss: 0.0623 - val_accuracy: 0.9830
# Epoch 7/15
# 491/491 [==============================] - 81s 164ms/step - loss: 0.2085 - accuracy: 0.9390 - val_loss: 0.0648 - val_accuracy: 0.9815
# Epoch 8/15
# 491/491 [==============================] - 86s 174ms/step - loss: 0.1947 - accuracy: 0.9440 - val_loss: 0.0564 - val_accuracy: 0.9830
# Epoch 9/15
# 491/491 [==============================] - 83s 170ms/step - loss: 0.1775 - accuracy: 0.9499 - val_loss: 0.0349 - val_accuracy: 0.9898
# Epoch 10/15
# 491/491 [==============================] - 84s 172ms/step - loss: 0.1609 - accuracy: 0.9553 - val_loss: 0.0558 - val_accuracy: 0.9833
# Epoch 11/15
# 491/491 [==============================] - 81s 165ms/step - loss: 0.1513 - accuracy: 0.9587 - val_loss: 0.0484 - val_accuracy: 0.9879
# Epoch 12/15
# 491/491 [==============================] - 81s 165ms/step - loss: 0.1599 - accuracy: 0.9572 - val_loss: 0.0281 - val_accuracy: 0.9904
# Epoch 13/15
# 491/491 [==============================] - 81s 165ms/step - loss: 0.1450 - accuracy: 0.9616 - val_loss: 0.0317 - val_accuracy: 0.9913
# Epoch 14/15
# 491/491 [==============================] - 82s 167ms/step - loss: 0.1478 - accuracy: 0.9593 - val_loss: 0.0257 - val_accuracy: 0.9921
# Epoch 15/15
# 491/491 [==============================] - 81s 165ms/step - loss: 0.1369 - accuracy: 0.9627 - val_loss: 0.0339 - val_accuracy: 0.9911

# %% [markdown]
# Plot the accuracy graph

# %%
plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()

# %%
model.save("model_trained.txt")
# Out:
# INFO:tensorflow:Assets written to: model_trained.txt/assets

# %%
#Testing the modelfrom sklearn.metrics import accuracy_score
import pandas as pd
y_test = pd.read_csv('Test.csv')
labels = y_test["ClassId"].values
img_paths = y_test["Path"].values
test_data=[]
for path in img_paths:
    image = Image.open(path)
    image = image.resize((30,30))
    test_data.append(np.array(image))
test_data = np.array(test_data)
pred = model.predict_classes(test_data)#Accuracy with the test data
from sklearn.metrics import accuracy_score
accuracy_score(labels, pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-63b0aa85c8ed> in <module>
#      10     test_data.append(np.array(image))
#      11 test_data = np.array(test_data)
# ---> 12 pred = model.predict_classes(test_data)#Accuracy with the test data
#      13 from sklearn.metrics import accuracy_score
#      14 accuracy_score(labels, pred)
#
# AttributeError: 'Sequential' object has no attribute 'predict_classes'

# %%
import numpy as np
import cv2
import pickle
from keras.models import load_model
 
#############################################
frameWidth= 640         # CAMERA RESOLUTION
frameHeight = 480
brightness = 180
threshold = 0.98         # PROBABLITY THRESHOLD
font = cv2.FONT_HERSHEY_SIMPLEX
##############################################
 
# SETUP THE VIDEO CAMERA
cap = cv2.VideoCapture("/dev/video2")
if not (cap.isOpened()):
    print("Could not open video device")
cap.set(3, frameWidth)
cap.set(4, frameHeight)
cap.set(10, brightness)
# IMPORT THE TRANNIED MODEL

model = load_model('traffic_recognition.h5')
 
def grayscale(img):
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    return img
def equalize(img):
    img =cv2.equalizeHist(img)
    return img
def preprocessing(img):
    img = grayscale(img)
   # img = equalize(img)
    #img = img/255
    return img
def getCalssName(classNo):
    if   classNo == 0: return 'Speed Limit 20 km/h'
    elif classNo == 1: return 'Speed Limit 30 km/h'
    elif classNo == 2: return 'Speed Limit 50 km/h'
    elif classNo == 3: return 'Speed Limit 60 km/h'
    elif classNo == 4: return 'Speed Limit 70 km/h'
    elif classNo == 5: return 'Speed Limit 80 km/h'
    elif classNo == 6: return 'End of Speed Limit 80 km/h'
    elif classNo == 7: return 'Speed Limit 100 km/h'
    elif classNo == 8: return 'Speed Limit 120 km/h'
    elif classNo == 9: return 'No passing'
    elif classNo == 10: return 'No passing for vechiles over 3.5 metric tons'
    elif classNo == 11: return 'Right-of-way at the next intersection'
    elif classNo == 12: return 'Priority road'
    elif classNo == 13: return 'Yield'
    elif classNo == 14: return 'Stop'
    elif classNo == 15: return 'No vechiles'
    elif classNo == 16: return 'Vechiles over 3.5 metric tons prohibited'
    elif classNo == 17: return 'No entry'
    elif classNo == 18: return 'General caution'
    elif classNo == 19: return 'Dangerous curve to the left'
    elif classNo == 20: return 'Dangerous curve to the right'
    elif classNo == 21: return 'Double curve'
    elif classNo == 22: return 'Bumpy road'
    elif classNo == 23: return 'Slippery road'
    elif classNo == 24: return 'Road narrows on the right'
    elif classNo == 25: return 'Road work'
    elif classNo == 26: return 'Traffic signals'
    elif classNo == 27: return 'Pedestrians'
    elif classNo == 28: return 'Children crossing'
    elif classNo == 29: return 'Bicycles crossing'
    elif classNo == 30: return 'Beware of ice/snow'
    elif classNo == 31: return 'Wild animals crossing'
    elif classNo == 32: return 'End of all speed and passing limits'
    elif classNo == 33: return 'Turn right ahead'
    elif classNo == 34: return 'Turn left ahead'
    elif classNo == 35: return 'Ahead only'
    elif classNo == 36: return 'Go straight or right'
    elif classNo == 37: return 'Go straight or left'
    elif classNo == 38: return 'Keep right'
    elif classNo == 39: return 'Keep left'
    elif classNo == 40: return 'Roundabout mandatory'
    elif classNo == 41: return 'End of no passing'
    elif classNo == 42: return 'End of no passing by vechiles over 3.5 metric tons'
 
while True:
 
    # READ IMAGE
    success, imgOrignal = cap.read()

    # PROCESS IMAGE
    img = imgOrignal
    img = cv2.resize(img, (30,30))
    #img = preprocessing(img)
    #cv2.imshow("Processed Image", img)
    img = img.reshape(1, 30, 30, 3)
    cv2.putText(imgOrignal, "CLASS: " , (20, 35), font, 0.75, (0, 0, 255), 2, cv2.LINE_AA)
    cv2.putText(imgOrignal, "PROBABILITY: ", (20, 75), font, 0.75, (0, 0, 255), 2, cv2.LINE_AA)
    # PREDICT IMAGE
    img=np.array(img)
    #cv2.imshow("sd",imgOrignal)
    predictions = model.predict(img)
    classIndex =np.argmax(predictions,axis=1)
    probabilityValue =np.amax(predictions)
    if probabilityValue > threshold:
        print(getCalssName(classIndex),"    ",round(probabilityValue*100,2))
        cv2.putText(imgOrignal,str(classIndex)+" "+str(getCalssName(classIndex)), (120, 35), font, 0.75, (0, 0, 255), 2, cv2.LINE_AA)
        cv2.putText(imgOrignal, str(round(probabilityValue*100,2) )+"%", (180, 75), font, 0.75, (0, 0, 255), 2, cv2.LINE_AA)
        cv2.imshow("Result", imgOrignal)
        if getCalssName(classIndex)=='Speed Limit 50 km/h':
            cv2.imwrite("filename.png", img)
    else:
        cv2.imshow("Result",imgOrignal)
    if cv2.waitKey(1) and 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Yield      99.04
# No vechiles      98.53
# Keep left      99.63
# Speed Limit 50 km/h      99.01
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      99.93
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      99.57
# Speed Limit 50 km/h      98.35
# Speed Limit 50 km/h      99.68
# Speed Limit 30 km/h      99.15
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      99.99
# Speed Limit 30 km/h      99.99
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      100.0
# Speed Limit 70 km/h      99.99
# Speed Limit 70 km/h      98.09
# Speed Limit 70 km/h      99.29
# Speed Limit 30 km/h      99.56
# Speed Limit 30 km/h      99.89
# Speed Limit 30 km/h      98.53
# Speed Limit 70 km/h      99.97
# Speed Limit 70 km/h      99.45
# General caution      99.99
# General caution      99.15
# Speed Limit 70 km/h      100.0
# Speed Limit 70 km/h      100.0
# Speed Limit 70 km/h      99.98
# Speed Limit 70 km/h      99.88
# General caution      100.0
# General caution      99.98
# General caution      98.99
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      99.97
# General caution      99.99
# General caution      99.97
# General caution      98.3
# Speed Limit 30 km/h      98.04
# Speed Limit 30 km/h      99.99
# Speed Limit 30 km/h      98.96
# Speed Limit 30 km/h      99.89
# Speed Limit 30 km/h      99.22
# Speed Limit 30 km/h      98.44
# General caution      99.36
# General caution      100.0
# General caution      99.97
# General caution      100.0
# General caution      99.94
# General caution      99.91
# Speed Limit 30 km/h      99.94
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      99.7
# Speed Limit 30 km/h      99.5
# General caution      99.82
# General caution      100.0
# General caution      100.0
# General caution      99.55
# General caution      100.0
# Bicycles crossing      99.35
# Bicycles crossing      98.05
# General caution      99.89
# General caution      99.98
# General caution      100.0
# General caution      99.99
# General caution      99.99
# General caution      99.99
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      99.22
# No vechiles      99.85
# Yield      99.99
# Yield      100.0
# Yield      99.89
# Yield      99.77
# Yield      99.98
# Keep right      99.97
# No passing for vechiles over 3.5 metric tons      99.71
# Ahead only      98.95
# Roundabout mandatory      99.93
# Wild animals crossing      99.77
# Double curve      99.52
# Turn left ahead      98.39
# Turn left ahead      98.93
# Turn left ahead      98.82
# Yield      98.45
# Yield      99.93
# Yield      99.4
# Yield      100.0
# General caution      99.86
# General caution      99.57
# No vechiles      99.0
# General caution      99.85
# General caution      100.0
# Children crossing      99.97
# Children crossing      100.0
# Children crossing      100.0
# Children crossing      99.95
# Children crossing      100.0
# Speed Limit 50 km/h      99.99
# Speed Limit 50 km/h      99.9
# Speed Limit 50 km/h      99.49
# Speed Limit 30 km/h      99.03
# Yield      99.13
# Children crossing      99.47
# Ahead only      98.76
# Ahead only      99.93
# Ahead only      99.69
# Turn left ahead      99.89
# Children crossing      99.62
# Children crossing      99.97
# Children crossing      99.55
# Children crossing      99.62
# No passing      99.94
# No passing      100.0
# No passing      99.86
# Children crossing      99.2
# Children crossing      99.33
# Children crossing      99.94
# Children crossing      99.84
# Turn left ahead      98.11
# Children crossing      99.83
# Children crossing      99.6
# Children crossing      99.56
# Children crossing      99.86
# Children crossing      99.84
# Children crossing      99.61
# Children crossing      99.57
# Children crossing      99.43
# Children crossing      99.92
# Children crossing      99.98
# Children crossing      100.0
# Children crossing      100.0
# Children crossing      99.79
# Children crossing      99.92
# Children crossing      99.21
# Children crossing      99.95
# Children crossing      98.61
# Children crossing      99.74
# Children crossing      99.26
# Road work      99.99
# Road work      98.22
# Bicycles crossing      99.39
# Bicycles crossing      98.72
# Yield      98.82
# Yield      99.58
# Speed Limit 120 km/h      99.84
# Speed Limit 120 km/h      99.9
# Speed Limit 120 km/h      98.13
# Speed Limit 120 km/h      99.17
# Speed Limit 120 km/h      99.75
# Speed Limit 120 km/h      98.55
# Speed Limit 120 km/h      99.9
# Speed Limit 120 km/h      99.99
# Children crossing      99.3
# Children crossing      99.71
# Priority road      99.32
# No passing      99.76
# Speed Limit 120 km/h      99.84
# No passing for vechiles over 3.5 metric tons      99.94
# Go straight or left      98.91
# Yield      99.76
# Ahead only      98.53
# Ahead only      99.71
# Ahead only      98.41
# Ahead only      99.92
# Ahead only      99.99
# Roundabout mandatory      98.93
# Speed Limit 30 km/h      98.85
# Speed Limit 30 km/h      98.35
# Speed Limit 30 km/h      98.95
# Speed Limit 30 km/h      99.22
# Road work      100.0
# Speed Limit 30 km/h      99.59
# General caution      99.83
# No vechiles      99.02
# Double curve      99.08
# Yield      99.96
# No vechiles      99.8
# Yield      98.56
# Priority road      99.33
# Yield      99.25
# Yield      99.9
# Slippery road      100.0
# Turn left ahead      100.0
# Roundabout mandatory      99.62
# Speed Limit 20 km/h      99.99
# Speed Limit 20 km/h      99.99
# Speed Limit 20 km/h      99.8
# Slippery road      99.44
# Slippery road      99.56
# Slippery road      99.32
# Slippery road      99.16
# Turn left ahead      100.0
# Turn left ahead      98.84
# Turn left ahead      99.51
# Slippery road      99.88
# Slippery road      100.0
# Slippery road      98.73
# Slippery road      98.61
# Slippery road      99.99
# Slippery road      99.41
# Slippery road      99.35
# Speed Limit 120 km/h      99.57
# Speed Limit 120 km/h      99.92
# Speed Limit 20 km/h      99.05
# No passing      99.59
# No passing      99.99
# No passing      100.0
# Speed Limit 50 km/h      99.94
# Speed Limit 50 km/h      99.99
# Speed Limit 50 km/h      99.99
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 20 km/h      98.46
# Speed Limit 20 km/h      99.97
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      99.88
# Speed Limit 20 km/h      99.84
# Speed Limit 20 km/h      100.0
# Speed Limit 30 km/h      99.95
# Keep right      99.91
# Priority road      100.0
# Keep left      100.0
# Keep left      98.22
# Keep right      100.0
# Keep right      100.0
# Keep right      100.0
# Turn right ahead      99.69
# General caution      100.0
# Road work      99.99
# Speed Limit 60 km/h      99.64
# No vechiles      99.8
# Roundabout mandatory      99.8
# Speed Limit 50 km/h      99.55
# Speed Limit 50 km/h      99.95
# Road work      100.0
# Road work      99.77
# Road work      100.0
# Road work      100.0
# Road work      100.0
# Priority road      99.71
# Roundabout mandatory      99.95
# Speed Limit 50 km/h      99.94
# Speed Limit 50 km/h      99.48
# Speed Limit 50 km/h      99.99
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      99.06
# Speed Limit 50 km/h      99.67
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      99.99
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      99.99
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      99.99
# Speed Limit 50 km/h      99.98
# Speed Limit 50 km/h      99.99
# Speed Limit 50 km/h      99.99
# Speed Limit 50 km/h      100.0
# Speed Limit 50 km/h      100.0
# No passing for vechiles over 3.5 metric tons      99.93
# General caution      100.0
# Yield      99.53
# Go straight or right      99.99
# Double curve      99.97
# Turn right ahead      99.79
# Turn right ahead      99.28
# Ahead only      98.24
# Bumpy road      98.99
# No passing      98.82
# No passing      98.89
# No passing      100.0
# No passing      100.0
# Speed Limit 120 km/h      98.29
# Speed Limit 120 km/h      99.86
# Dangerous curve to the right      98.27
# Vechiles over 3.5 metric tons prohibited      100.0
# Vechiles over 3.5 metric tons prohibited      100.0
# Turn right ahead      99.83
# Roundabout mandatory      99.9
# Speed Limit 50 km/h      98.95
# Keep right      100.0
# Keep right      100.0
# Keep right      100.0
# Keep right      100.0
# Keep right      99.34
# Speed Limit 50 km/h      98.66
# Speed Limit 50 km/h      99.42
# Roundabout mandatory      98.49
# Speed Limit 50 km/h      98.58
# Speed Limit 50 km/h      99.38
# Speed Limit 50 km/h      98.6
# Speed Limit 50 km/h      98.86
# Speed Limit 50 km/h      98.71
# Roundabout mandatory      99.97
# Roundabout mandatory      99.58
# Roundabout mandatory      99.0
# Roundabout mandatory      99.99
# Roundabout mandatory      99.99
# Roundabout mandatory      99.98
# Roundabout mandatory      99.99
# Roundabout mandatory      99.98
# Roundabout mandatory      99.99
# Roundabout mandatory      99.97
# Roundabout mandatory      99.97
# Roundabout mandatory      99.98
# Roundabout mandatory      99.99
# Roundabout mandatory      99.96
# Roundabout mandatory      99.94
# Roundabout mandatory      99.9
# Roundabout mandatory      99.55
# Roundabout mandatory      99.98
# Roundabout mandatory      100.0
# Roundabout mandatory      99.97
# Speed Limit 50 km/h      99.71
# Speed Limit 50 km/h      99.93
# Roundabout mandatory      99.03
# Roundabout mandatory      99.28
# Keep right      99.84
# Keep right      100.0
# Keep right      100.0
# Keep right      100.0
# Keep right      100.0
# Keep right      100.0
# Keep right      99.84
# Keep right      100.0
# Keep right      99.6
# Keep right      99.46
# Keep right      99.64
# Keep right      100.0
# Keep right      100.0
# Keep right      99.99
# Keep right      100.0
# Keep right      100.0
# Keep right      99.99
# Keep right      99.19
# Keep right      99.71
# Double curve      99.11
# Double curve      99.46
# Double curve      99.65
# Double curve      99.95
# Double curve      99.57
# Double curve      99.88
# Double curve      99.48
# Roundabout mandatory      98.63
# Keep right      99.39
# Keep right      99.77
# Turn right ahead      99.84
# Speed Limit 70 km/h      99.61
# Roundabout mandatory      99.9
# Roundabout mandatory      99.99
# Roundabout mandatory      99.73
# Roundabout mandatory      99.84
# Roundabout mandatory      99.87
# Roundabout mandatory      99.96
# Roundabout mandatory      99.85
# Roundabout mandatory      99.29
# Roundabout mandatory      98.5
# Roundabout mandatory      99.21
# Roundabout mandatory      99.3
# Roundabout mandatory      98.38
# Roundabout mandatory      99.93
# Roundabout mandatory      99.89
# Roundabout mandatory      99.78
# Roundabout mandatory      99.99
# Roundabout mandatory      99.93
# Roundabout mandatory      99.75
# Roundabout mandatory      99.81
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.99
# Turn right ahead      99.99
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.99
# Turn right ahead      99.99
# Turn right ahead      99.97
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      98.42
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.99
# Turn right ahead      99.9
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.99
# Turn right ahead      99.98
# Turn right ahead      99.44
# Turn right ahead      99.94
# Turn right ahead      99.92
# No passing      99.81
# No passing      99.93
# No passing      99.98
# No passing      99.99
# Speed Limit 50 km/h      98.93
# No vechiles      99.62
# No passing      99.99
# Ahead only      99.1
# No passing      99.82
# Go straight or right      99.42
# Go straight or right      98.72
# Go straight or right      99.77
# Go straight or right      99.42
# Go straight or right      99.51
# Turn right ahead      100.0
# Turn right ahead      99.69
# Turn right ahead      100.0
# Turn right ahead      99.97
# Turn right ahead      99.69
# Turn right ahead      99.95
# Turn right ahead      99.94
# Turn right ahead      100.0
# Turn right ahead      99.85
# Turn right ahead      99.99
# Turn right ahead      99.88
# Turn right ahead      99.99
# Turn right ahead      99.98
# Turn right ahead      99.95
# Turn right ahead      99.96
# Turn right ahead      99.99
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.98
# Turn right ahead      99.94
# Turn right ahead      98.93
# Turn right ahead      99.88
# Turn right ahead      99.8
# Turn right ahead      99.97
# Turn right ahead      99.96
# Turn right ahead      99.97
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.98
# Turn right ahead      98.92
# Turn right ahead      100.0
# Roundabout mandatory      99.99
# Speed Limit 50 km/h      98.51
# Speed Limit 50 km/h      99.79
# Ahead only      99.95
# Dangerous curve to the right      100.0
# Slippery road      98.78
# Yield      99.96
# No vechiles      99.2
# No passing      99.22
# Bumpy road      99.97
# No passing      99.97
# Turn right ahead      99.9
# No vechiles      99.99
# No passing      99.98
# No vechiles      99.44
# Turn right ahead      98.96
# Turn right ahead      99.93
# Turn right ahead      99.66
# Turn right ahead      99.98
# No vechiles      99.31
# Turn right ahead      99.68
# Turn right ahead      99.99
# Turn right ahead      99.98
# Turn right ahead      100.0
# Turn right ahead      99.98
# Turn right ahead      100.0
# Speed Limit 60 km/h      99.99
# Speed Limit 60 km/h      99.99
# Speed Limit 60 km/h      99.99
# Speed Limit 60 km/h      99.37
# Roundabout mandatory      98.52
# Keep right      99.59
# Keep right      99.95
# Keep right      99.91
# Keep right      99.03
# Roundabout mandatory      99.7
# Roundabout mandatory      99.9
# Speed Limit 60 km/h      99.38
# Speed Limit 60 km/h      98.34
# Speed Limit 60 km/h      100.0
# Speed Limit 60 km/h      100.0
# Turn right ahead      99.98
# Turn right ahead      98.81
# Turn right ahead      98.84
# Speed Limit 60 km/h      99.91
# Speed Limit 60 km/h      99.6
# Speed Limit 60 km/h      99.96
# Speed Limit 60 km/h      99.87
# Speed Limit 60 km/h      99.0
# Speed Limit 60 km/h      99.1
# Speed Limit 60 km/h      98.05
# Speed Limit 60 km/h      99.32
# Speed Limit 60 km/h      99.79
# Speed Limit 60 km/h      99.3
# Speed Limit 60 km/h      98.84
# Speed Limit 60 km/h      99.81
# Speed Limit 60 km/h      99.69
# Roundabout mandatory      98.55
# Keep right      99.56
# Keep right      99.31
# Speed Limit 120 km/h      99.99
# Speed Limit 120 km/h      98.58
# Speed Limit 120 km/h      99.99
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      99.77
# Speed Limit 120 km/h      99.75
# Speed Limit 120 km/h      98.59
# Speed Limit 120 km/h      99.2
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      99.99
# Speed Limit 120 km/h      99.45
# Speed Limit 120 km/h      99.63
# Speed Limit 120 km/h      99.94
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      99.86
# Speed Limit 120 km/h      98.8
# Speed Limit 120 km/h      98.65
# Speed Limit 120 km/h      99.84
# Speed Limit 120 km/h      99.95
# Keep right      99.46
# Keep right      99.69
# Keep right      99.92
# Keep right      99.96
# Keep right      99.66
# Keep right      98.83
# Keep right      98.7
# Keep right      99.83
# Speed Limit 120 km/h      99.94
# Speed Limit 120 km/h      99.36
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      99.98
# Speed Limit 20 km/h      99.89
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      99.97
# Speed Limit 20 km/h      99.96
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 20 km/h      99.29
# Speed Limit 20 km/h      99.42
# Speed Limit 120 km/h      99.97
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      99.99
# Speed Limit 20 km/h      99.94
# Speed Limit 20 km/h      99.96
# Speed Limit 20 km/h      99.97
# Speed Limit 20 km/h      99.98
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      100.0
# Speed Limit 20 km/h      99.88
# Speed Limit 20 km/h      99.95
# Speed Limit 30 km/h      99.96
# No passing      99.95
# No passing      98.38
# Priority road      99.06
# Priority road      99.03
# Priority road      98.62
# Priority road      98.55
# Turn right ahead      98.09
# Speed Limit 60 km/h      99.64
# Speed Limit 60 km/h      99.69
# Speed Limit 60 km/h      99.7
# Turn right ahead      99.63
# Roundabout mandatory      98.18
# Roundabout mandatory      99.77
# Roundabout mandatory      99.66
# Roundabout mandatory      99.62
# Roundabout mandatory      99.94
# Roundabout mandatory      99.47
# Roundabout mandatory      99.37
# Roundabout mandatory      100.0
# Roundabout mandatory      99.47
# Roundabout mandatory      99.96
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Keep right      99.51
# Keep right      99.57
# Roundabout mandatory      100.0
# Roundabout mandatory      99.3
# Roundabout mandatory      99.84
# Roundabout mandatory      99.97
# Roundabout mandatory      99.98
# Roundabout mandatory      98.87
# Roundabout mandatory      99.65
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.99
# Roundabout mandatory      99.87
# Roundabout mandatory      99.99
# Roundabout mandatory      99.99
# Roundabout mandatory      99.32
# Keep right      100.0
# Speed Limit 30 km/h      99.99
# Wild animals crossing      99.98
# No vechiles      99.81
# General caution      100.0
# Ahead only      98.53
# Turn right ahead      98.82
# Keep left      99.99
# Keep left      100.0
# Keep left      100.0
# Keep left      99.99
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      99.98
# Keep left      99.32
# Ahead only      99.24
# Ahead only      99.98
# Keep right      98.65
# Keep right      100.0
# Right-of-way at the next intersection      99.62
# Right-of-way at the next intersection      99.99
# Right-of-way at the next intersection      99.83
# Double curve      99.09
# Turn right ahead      99.62
# No passing      100.0
# No passing      99.92
# No passing      99.65
# Wild animals crossing      99.31
# Yield      99.61
# Keep right      100.0
# Turn left ahead      99.6
# Yield      99.95
# No vechiles      98.91
# No passing for vechiles over 3.5 metric tons      99.56
# Road work      99.47
# No passing      98.13
# Yield      99.98
# Yield      99.46
# Yield      100.0
# Yield      100.0
# Yield      100.0
# Wild animals crossing      98.74
# Wild animals crossing      98.35
# Wild animals crossing      99.61
# Wild animals crossing      99.99
# Wild animals crossing      99.73
# Turn left ahead      99.42
# Turn left ahead      99.79
# Turn right ahead      98.2
# Go straight or left      98.99
# Traffic signals      99.05
# Right-of-way at the next intersection      99.92
# Right-of-way at the next intersection      100.0
# Turn left ahead      99.44
# Go straight or left      99.64
# Roundabout mandatory      99.67
# Bicycles crossing      98.99
# Bicycles crossing      99.9
# Bicycles crossing      99.42
# Bicycles crossing      99.99
# Bicycles crossing      99.87
# Bicycles crossing      99.98
# Bicycles crossing      99.98
# Bicycles crossing      100.0
# Bicycles crossing      99.67
# Bicycles crossing      99.81
# Bicycles crossing      98.42
# Bicycles crossing      98.82
# Bicycles crossing      99.37
# Keep right      98.13
# Go straight or left      99.88
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      99.95
# Dangerous curve to the right      98.62
# Keep right      99.68
# Ahead only      99.87
# Ahead only      99.88
# Go straight or left      100.0
# Go straight or left      99.99
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      99.99
# Keep left      100.0
# Go straight or left      99.27
# Go straight or left      99.13
# Go straight or left      99.97
# Roundabout mandatory      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Ahead only      100.0
# Ahead only      100.0
# Roundabout mandatory      100.0
# Ahead only      99.92
# Roundabout mandatory      99.64
# Roundabout mandatory      99.95
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Turn left ahead      99.66
# Keep left      99.85
# Roundabout mandatory      99.98
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.88
# Vechiles over 3.5 metric tons prohibited      99.53
# Turn right ahead      99.99
# Right-of-way at the next intersection      99.96
# Turn right ahead      99.96
# Turn right ahead      99.55
# Turn right ahead      99.49
# Turn right ahead      98.19
# Vechiles over 3.5 metric tons prohibited      99.16
# Vechiles over 3.5 metric tons prohibited      99.06
# Vechiles over 3.5 metric tons prohibited      99.6
# Turn right ahead      99.96
# Turn right ahead      100.0
# Turn right ahead      99.99
# Turn right ahead      99.91
# Turn right ahead      99.79
# Turn right ahead      98.64
# Roundabout mandatory      99.96
# Roundabout mandatory      99.94
# Roundabout mandatory      99.95
# Roundabout mandatory      99.93
# Roundabout mandatory      99.87
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.81
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.98
# Roundabout mandatory      99.93
# Roundabout mandatory      99.99
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Keep right      99.54
# Keep right      99.87
# Keep right      99.91
# Keep right      99.99
# Keep right      99.95
# Keep right      100.0
# Keep right      100.0
# Keep right      99.96
# Keep right      99.9
# Keep right      99.93
# Keep right      99.95
# Keep right      99.49
# Keep right      99.59
# Keep right      98.35
# Keep right      99.89
# Keep right      99.81
# Keep right      99.18
# Keep right      99.79
# No vechiles      99.91
# Priority road      99.23
# General caution      98.7
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      98.01
# Turn right ahead      99.49
# Turn right ahead      99.97
# Turn right ahead      99.92
# Children crossing      99.12
# Children crossing      99.73
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or right      99.47
# Ahead only      99.92
# Go straight or left      99.93
# Turn left ahead      99.03
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Ahead only      98.8
# Ahead only      99.99
# Ahead only      100.0
# Ahead only      100.0
# Ahead only      100.0
# Ahead only      100.0
# Ahead only      99.99
# Ahead only      99.55
# Ahead only      98.94
# Ahead only      99.46
# Ahead only      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      99.99
# Roundabout mandatory      99.01
# Keep left      99.6
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Roundabout mandatory      99.85
# Roundabout mandatory      98.6
# Turn left ahead      100.0
# Keep left      99.85
# Keep left      99.92
# Keep left      99.67
# Keep left      100.0
# Keep left      98.77
# Keep left      99.69
# Keep left      99.87
# Keep left      99.88
# Keep left      100.0
# Keep left      98.48
# Keep left      99.87
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Go straight or left      99.88
# Go straight or left      99.99
# Go straight or left      99.99
# Go straight or left      100.0
# Go straight or left      99.99
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      99.19
# Keep left      99.52
# Bumpy road      99.45
# Bicycles crossing      98.98
# Bicycles crossing      98.25
# Yield      99.97
# Yield      98.69
# Turn left ahead      99.96
# Speed Limit 30 km/h      99.94
# Yield      99.5
# Yield      99.47
# No passing      99.92
# Road work      99.6
# No passing      100.0
# Double curve      99.53
# No passing      98.03
# No passing      99.66
# No passing      99.7
# No passing      99.99
# No passing      99.96
# No passing      100.0
# No passing      99.99
# No passing      99.03
# General caution      99.39
# General caution      99.99
# General caution      99.98
# General caution      99.92
# General caution      99.88
# General caution      99.48
# General caution      99.75
# General caution      99.99
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      99.99
# Yield      99.76
# Bicycles crossing      98.05
# General caution      98.77
# Ahead only      99.46
# Yield      100.0
# Yield      99.86
# Double curve      99.88
# Double curve      99.95
# Double curve      99.98
# Yield      100.0
# End of no passing      98.13
# Yield      99.86
# No passing      100.0
# No passing      100.0
# No passing      99.94
# No passing      99.98
# No passing      100.0
# No passing      100.0
# Speed Limit 120 km/h      99.19
# Bumpy road      100.0
# Go straight or left      98.56
# Turn left ahead      100.0
# Roundabout mandatory      99.99
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# No vechiles      100.0
# Turn left ahead      100.0
# Yield      99.49
# Keep right      98.9
# Keep right      98.08
# Roundabout mandatory      99.1
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.72
# Roundabout mandatory      99.85
# Keep right      99.17
# Roundabout mandatory      99.94
# Keep right      99.88
# Keep right      100.0
# Children crossing      99.4
# No vechiles      99.91
# Speed Limit 70 km/h      99.6
# Speed Limit 70 km/h      98.36
# No vechiles      98.53
# No vechiles      99.93
# No vechiles      99.58
# Keep right      99.52
# Keep right      99.69
# Yield      99.99
# Keep right      99.8
# Keep right      99.98
# Keep right      99.91
# Keep right      99.99
# Keep right      100.0
# Yield      100.0
# Yield      100.0
# Keep right      100.0
# Keep right      99.81
# Keep right      100.0
# Keep right      100.0
# Keep right      99.98
# Yield      100.0
# Keep right      99.68
# Keep right      99.89
# Keep right      99.72
# Keep right      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.92
# Roundabout mandatory      99.72
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.74
# Roundabout mandatory      99.98
# Roundabout mandatory      99.99
# Roundabout mandatory      99.99
# Roundabout mandatory      99.42
# Roundabout mandatory      98.28
# Keep right      99.09
# Roundabout mandatory      99.87
# Roundabout mandatory      99.99
# Roundabout mandatory      99.13
# Roundabout mandatory      100.0
# Roundabout mandatory      99.99
# Roundabout mandatory      99.99
# Roundabout mandatory      99.89
# Roundabout mandatory      99.82
# Roundabout mandatory      99.12
# Roundabout mandatory      99.75
# Roundabout mandatory      100.0
# Roundabout mandatory      99.56
# Roundabout mandatory      99.98
# Roundabout mandatory      99.16
# Roundabout mandatory      99.7
# Roundabout mandatory      100.0
# Roundabout mandatory      99.99
# Roundabout mandatory      99.96
# Roundabout mandatory      99.86
# Roundabout mandatory      99.9
# Roundabout mandatory      99.44
# Roundabout mandatory      99.92
# Roundabout mandatory      98.52
# Roundabout mandatory      99.97
# Roundabout mandatory      98.41
# Roundabout mandatory      98.8
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      98.37
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Vechiles over 3.5 metric tons prohibited      98.2
# Keep left      100.0
# Go straight or right      99.25
# Roundabout mandatory      98.02
# Roundabout mandatory      99.89
# End of all speed and passing limits      99.84
# Slippery road      98.37
# Turn left ahead      99.98
# Turn left ahead      99.97
# Turn left ahead      100.0
# Turn left ahead      99.98
# Turn left ahead      99.94
# Turn left ahead      99.99
# Ahead only      100.0
# Ahead only      100.0
# Ahead only      100.0
# Turn left ahead      99.98
# Turn left ahead      100.0
# Turn left ahead      100.0
# Turn left ahead      99.99
# Turn left ahead      99.99
# Turn left ahead      100.0
# Roundabout mandatory      100.0
# Vechiles over 3.5 metric tons prohibited      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.99
# Keep right      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.05
# Roundabout mandatory      100.0
# Roundabout mandatory      99.82
# Keep right      100.0
# Keep right      100.0
# Turn right ahead      100.0
# Turn right ahead      99.92
# Turn right ahead      100.0
# Keep right      100.0
# Keep right      100.0
# Keep right      100.0
# Keep right      99.96
# Keep right      99.3
# Keep right      100.0
# Keep right      100.0
# Keep right      100.0
# Keep right      99.99
# Keep right      100.0
# Keep right      99.24
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn left ahead      98.14
# Keep right      99.41
# Keep right      98.78
# Keep right      99.9
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      98.22
# Turn right ahead      99.66
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.83
# Turn right ahead      100.0
# Turn right ahead      98.72
# Keep right      99.96
# Keep right      99.98
# Keep right      100.0
# Keep right      100.0
# Keep right      100.0
# Keep right      100.0
# Keep right      99.97
# Keep right      99.89
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.98
# Turn right ahead      99.99
# Turn right ahead      99.99
# Turn right ahead      99.78
# Turn right ahead      99.97
# Turn right ahead      99.96
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.95
# Turn right ahead      99.38
# Turn right ahead      98.26
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.46
# Turn right ahead      99.95
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Turn right ahead      100.0
# Turn right ahead      99.99
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      99.93
# Go straight or left      98.96
# Roundabout mandatory      99.97
# Keep right      99.86
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Vechiles over 3.5 metric tons prohibited      99.36
# Roundabout mandatory      99.99
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.99
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Go straight or right      99.98
# Go straight or right      100.0
# Speed Limit 60 km/h      99.06
# Yield      98.9
# Yield      98.57
# Turn right ahead      100.0
# No passing      99.81
# Priority road      99.64
# Yield      99.4
# Keep left      98.88
# Keep left      100.0
# Keep left      99.99
# Vechiles over 3.5 metric tons prohibited      99.53
# Vechiles over 3.5 metric tons prohibited      99.51
# Turn right ahead      99.94
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      100.0
# Turn right ahead      99.81
# Vechiles over 3.5 metric tons prohibited      99.83
# Go straight or right      100.0
# Go straight or right      100.0
# Turn right ahead      99.71
# Go straight or right      99.0
# Go straight or right      100.0
# Go straight or right      99.99
# Roundabout mandatory      100.0
# Vechiles over 3.5 metric tons prohibited      99.86
# Vechiles over 3.5 metric tons prohibited      99.98
# Vechiles over 3.5 metric tons prohibited      99.0
# Vechiles over 3.5 metric tons prohibited      99.78
# Turn right ahead      99.99
# Turn right ahead      99.88
# Vechiles over 3.5 metric tons prohibited      99.7
# Roundabout mandatory      99.74
# Roundabout mandatory      99.9
# Roundabout mandatory      99.96
# Roundabout mandatory      99.95
# Roundabout mandatory      99.61
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.8
# Go straight or left      99.03
# Ahead only      98.14
# Go straight or left      100.0
# Children crossing      99.26
# Speed Limit 30 km/h      100.0
# Bicycles crossing      98.23
# Speed Limit 30 km/h      99.31
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      99.02
# Speed Limit 30 km/h      99.97
# Slippery road      98.4
# Wild animals crossing      99.35
# Turn right ahead      98.66
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      99.66
# Speed Limit 30 km/h      99.93
# Speed Limit 30 km/h      99.83
# Speed Limit 30 km/h      98.84
# Speed Limit 30 km/h      99.68
# Speed Limit 30 km/h      100.0
# Speed Limit 30 km/h      99.98
# Speed Limit 30 km/h      99.75
# Speed Limit 30 km/h      99.85
# Speed Limit 30 km/h      99.79
# Speed Limit 30 km/h      99.9
# Speed Limit 30 km/h      99.14
# Speed Limit 30 km/h      99.56
# Roundabout mandatory      99.68
# No passing      98.71
# No passing      99.98
# No passing      100.0
# Speed Limit 30 km/h      99.97
# Speed Limit 30 km/h      99.11
# No passing for vechiles over 3.5 metric tons      99.07
# No passing for vechiles over 3.5 metric tons      98.24
# No passing for vechiles over 3.5 metric tons      99.12
# No passing for vechiles over 3.5 metric tons      99.16
# No passing for vechiles over 3.5 metric tons      99.22
# No passing for vechiles over 3.5 metric tons      99.98
# No passing for vechiles over 3.5 metric tons      99.94
# No passing for vechiles over 3.5 metric tons      99.89
# No passing for vechiles over 3.5 metric tons      99.87
# No passing for vechiles over 3.5 metric tons      99.43
# No passing for vechiles over 3.5 metric tons      98.08
# Road work      99.95
# Road work      99.95
# Road work      99.52
# Road work      99.93
# Road work      99.96
# Road work      99.9
# Road work      99.36
# Road work      99.39
# Road work      99.97
# Road work      99.99
# Road work      99.64
# Road work      99.79
# No passing      99.49
# No passing      100.0
# No passing      100.0
# No vechiles      98.84
# No vechiles      99.98
# Speed Limit 70 km/h      98.53
# Dangerous curve to the left      99.95
# Dangerous curve to the left      100.0
# Dangerous curve to the left      100.0
# No vechiles      98.21
# No vechiles      98.12
# No vechiles      98.1
# No vechiles      99.49
# No passing for vechiles over 3.5 metric tons      99.01
# Yield      99.15
# No vechiles      99.35
# No passing for vechiles over 3.5 metric tons      98.48
# Yield      100.0
# Priority road      99.76
# No vechiles      100.0
# No vechiles      98.47
# No vechiles      99.35
# No vechiles      99.03
# Priority road      99.98
# Priority road      99.98
# Priority road      99.0
# No passing      99.96
# Slippery road      99.65
# Slippery road      99.14
# Slippery road      99.98
# Slippery road      100.0
# Slippery road      99.33
# Go straight or left      100.0
# Go straight or left      100.0
# Slippery road      98.67
# Bumpy road      99.88
# Turn left ahead      99.23
# Turn left ahead      99.86
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.92
# Roundabout mandatory      100.0
# Double curve      100.0
# Double curve      100.0
# Double curve      99.71
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.98
# Roundabout mandatory      98.48
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Turn right ahead      99.73
# Roundabout mandatory      99.98
# Roundabout mandatory      99.98
# Keep left      99.95
# Keep left      99.96
# End of no passing      99.64
# End of no passing      99.82
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.48
# Roundabout mandatory      99.97
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# End of no passing      100.0
# End of no passing      100.0
# Go straight or left      100.0
# Go straight or left      100.0
# Go straight or left      99.84
# Turn right ahead      99.71
# Go straight or left      98.62
# Roundabout mandatory      99.9
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Go straight or left      98.72
# Go straight or left      100.0
# Go straight or left      100.0
# No passing      99.06
# No passing      98.01
# Roundabout mandatory      99.13
# Roundabout mandatory      100.0
# Turn right ahead      99.68
# Vechiles over 3.5 metric tons prohibited      99.23
# Yield      100.0
# Speed Limit 70 km/h      99.99
# No vechiles      100.0
# No vechiles      99.63
# Keep right      100.0
# General caution      99.9
# General caution      99.7
# Yield      99.05
# Yield      100.0
# Yield      100.0
# Yield      100.0
# Yield      100.0
# Yield      99.92
# General caution      99.05
# No passing for vechiles over 3.5 metric tons      99.51
# Yield      99.64
# Yield      99.85
# Yield      100.0
# Yield      99.99
# Yield      99.03
# No passing      98.4
# No passing      98.02
# Speed Limit 120 km/h      98.04
# Speed Limit 120 km/h      99.95
# Stop      99.48
# Yield      98.91
# Yield      99.07
# Stop      99.47
# End of all speed and passing limits      98.11
# End of all speed and passing limits      98.9
# End of all speed and passing limits      99.83
# Priority road      99.34
# Priority road      99.43
# Priority road      99.89
# Priority road      99.79
# Slippery road      99.98
# Priority road      98.58
# Slippery road      100.0
# Turn left ahead      98.62
# End of no passing      99.19
# Slippery road      99.97
# Priority road      99.05
# Yield      99.82
# Yield      99.7
# Yield      98.26
# Yield      99.45
# Yield      99.11
# Yield      99.07
# Keep right      99.3
# Keep right      99.66
# Keep right      99.99
# Keep right      100.0
# Keep right      99.86
# Keep right      98.0
# Keep left      99.75
# Road work      99.64
# Road work      99.73
# Road work      99.94
# Road work      99.99
# Road work      99.48
# Keep left      99.95
# Keep left      99.99
# Keep left      100.0
# Keep left      99.98
# Keep right      98.91
# Children crossing      99.95
# Children crossing      98.96
# Bumpy road      98.91
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 120 km/h      100.0
# Speed Limit 30 km/h      99.94
# Speed Limit 30 km/h      99.99
# Speed Limit 30 km/h      99.31
# Speed Limit 30 km/h      98.76
# Keep left      99.99
# Keep left      99.77
# Keep left      99.99
# Keep left      99.98
# Keep left      99.49
# Bicycles crossing      99.54
# Priority road      100.0
# Turn right ahead      99.04
# Turn right ahead      99.82
# Ahead only      99.17
# Turn right ahead      99.65
# Keep right      99.53
# Double curve      99.81
# Keep right      99.98
# Keep right      99.99
# Keep right      100.0
# Keep right      99.97
# Children crossing      99.28
# Yield      98.88
# Yield      99.85
# Yield      99.1
# End of all speed and passing limits      99.25
# Speed Limit 120 km/h      99.81
# Yield      100.0
# Yield      99.99
# Keep left      100.0
# Keep left      99.95
# Yield      98.62
# Yield      98.49
# Yield      99.73
# Yield      99.0
# Speed Limit 30 km/h      99.16
# Speed Limit 30 km/h      99.85
# Speed Limit 30 km/h      98.46
# No passing      98.07
# Turn left ahead      99.1
# Speed Limit 70 km/h      98.05
# Speed Limit 30 km/h      99.48
# Speed Limit 30 km/h      98.08
# Speed Limit 30 km/h      98.86
# Speed Limit 30 km/h      98.71
# Speed Limit 30 km/h      98.52
# Speed Limit 30 km/h      99.57
# Speed Limit 30 km/h      99.86
# Yield      99.83
# Turn left ahead      99.77
# Turn left ahead      99.94
# Right-of-way at the next intersection      100.0
# Turn left ahead      99.91
# Turn left ahead      98.34
# Roundabout mandatory      99.85
# No vechiles      99.22
# No vechiles      100.0
# No passing      99.98
# No passing      99.98
# No passing      99.82
# No passing      99.99
# No passing      100.0
# No passing      100.0
# Speed Limit 120 km/h      99.99
# No vechiles      99.89
# No vechiles      98.63
# No vechiles      99.32
# No vechiles      98.64
# General caution      100.0
# General caution      99.86
# General caution      99.95
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      99.12
# General caution      100.0
# General caution      98.67
# Priority road      99.94
# Go straight or left      98.66
# Bumpy road      99.21
# Keep left      99.04
# Keep left      98.12
# Keep left      98.85
# Keep left      99.24
# Keep left      98.44
# Keep left      98.86
# Yield      98.35
# Yield      99.63
# Yield      98.68
# Yield      99.29
# Yield      99.5
# No vechiles      100.0
# No vechiles      99.94
# No vechiles      98.86
# No vechiles      99.98
# No vechiles      99.92
# No vechiles      99.99
# General caution      99.92
# No vechiles      99.61
# General caution      99.61
# General caution      99.64
# General caution      100.0
# Ahead only      99.96
# Yield      98.83
# General caution      99.84
# General caution      99.3
# General caution      99.98
# General caution      99.98
# General caution      100.0
# General caution      100.0
# General caution      99.99
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      100.0
# General caution      99.91
# General caution      99.97
# General caution      99.87
# General caution      98.97
# General caution      98.95
# General caution      100.0
# General caution      99.94
# General caution      99.83
# General caution      99.52
# General caution      100.0
# General caution      99.91
# General caution      99.93
# General caution      99.98
# General caution      99.98
# General caution      99.86
# General caution      99.97
# General caution      99.92
# General caution      99.98
# General caution      99.62
# General caution      99.99
# General caution      99.9
# General caution      100.0
# General caution      99.96
# General caution      100.0
# General caution      99.94
# General caution      100.0
# General caution      99.76
# General caution      99.98
# General caution      98.52
# General caution      99.92
# General caution      99.75
# General caution      100.0
# General caution      99.69
# General caution      100.0
# General caution      99.67
# General caution      100.0
# General caution      99.31
# General caution      100.0
# General caution      99.54
# General caution      99.65
# Wild animals crossing      98.48
# Children crossing      99.95
# Children crossing      99.97
# Go straight or left      100.0
# Keep left      100.0
# Go straight or left      99.31
# Keep left      100.0
# Keep left      99.94
# Go straight or left      99.77
# Go straight or left      100.0
# Go straight or left      99.99
# Go straight or left      100.0
# Bumpy road      98.84
# Road work      99.41
# Keep left      99.01
# Children crossing      99.89
# Children crossing      99.13
# Children crossing      99.52
# Children crossing      99.85
# Children crossing      99.48
# Children crossing      99.95
# Double curve      99.65
# Bumpy road      99.52
# Bumpy road      99.92
# Bumpy road      98.21
# Bumpy road      98.73
# Bumpy road      99.09
# Bumpy road      98.62
# Bumpy road      99.79
# Bumpy road      99.63
# Bumpy road      99.22
# Bumpy road      98.75
# Bumpy road      99.18
# Bumpy road      99.85
# Bumpy road      98.35
# Keep left      99.99
# Road work      100.0
# Keep right      99.38
# Keep right      99.95
# Priority road      98.17
# Priority road      99.96
# Priority road      99.81
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.85
# Roundabout mandatory      99.97
# Roundabout mandatory      99.67
# Roundabout mandatory      99.61
# Roundabout mandatory      99.99
# Roundabout mandatory      100.0
# Roundabout mandatory      99.99
# Roundabout mandatory      99.99
# Roundabout mandatory      99.93
# Roundabout mandatory      99.97
# Roundabout mandatory      99.8
# Roundabout mandatory      99.95
# Roundabout mandatory      99.99
# Roundabout mandatory      99.89
# Roundabout mandatory      99.48
# Roundabout mandatory      99.72
# Roundabout mandatory      98.65
# Keep right      98.91
# Keep right      98.86
# Keep right      98.63
# Roundabout mandatory      98.07
# Roundabout mandatory      99.27
# Roundabout mandatory      98.84
# Roundabout mandatory      98.58
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.87
# Roundabout mandatory      99.98
# Roundabout mandatory      99.98
# Roundabout mandatory      99.93
# Roundabout mandatory      99.99
# Roundabout mandatory      99.82
# Roundabout mandatory      99.94
# Roundabout mandatory      99.99
# Roundabout mandatory      99.99
# Roundabout mandatory      99.96
# Roundabout mandatory      100.0
# Roundabout mandatory      99.96
# Yield      98.56
# Keep left      98.24
# Road work      99.92
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      100.0
# Keep left      99.85
# No passing      98.88
# Go straight or right      98.18
# Yield      99.53
# Turn right ahead      99.88
# Yield      99.52
# Yield      98.35
# No vechiles      99.05
# No vechiles      98.39
# Yield      98.87
# No vechiles      99.55
# Priority road      99.76
# Go straight or right      98.88
# Go straight or right      98.68
# Priority road      98.85
# No passing      100.0
# No passing      100.0
# Speed Limit 120 km/h      100.0
# Keep right      100.0
# Keep right      99.99
# Keep right      99.81
# Keep right      100.0
# Wild animals crossing      99.57
# Yield      99.01
# No vechiles      98.33
# No passing      100.0
# Keep right      99.67
# Wild animals crossing      99.81
# No passing      100.0
# Turn right ahead      99.8
# No entry      99.54
# Turn right ahead      98.67
# Turn right ahead      99.86
# Turn right ahead      99.99
# Turn right ahead      100.0
# No entry      98.83
# No passing for vechiles over 3.5 metric tons      99.73
# Yield      99.99
# Yield      99.99
# No passing for vechiles over 3.5 metric tons      99.03
# No passing      99.98
# No passing      99.1
# No passing      98.44
# No vechiles      99.88
# No vechiles      99.74
# No vechiles      99.65
# No vechiles      99.91
# No vechiles      99.97
# No vechiles      99.97
# No vechiles      99.98
# No vechiles      99.88
# No vechiles      99.83
# No vechiles      100.0
# No vechiles      99.91
# No vechiles      99.12
# No vechiles      99.61
# No vechiles      99.93
# No vechiles      98.4
# No vechiles      99.81
# No vechiles      99.71
# Yield      99.42
# Yield      98.45
# No vechiles      99.57
# No vechiles      99.28
# No vechiles      98.95
# No vechiles      99.51
# No vechiles      99.44
# No vechiles      99.89
# No vechiles      99.68
# No vechiles      99.85
# No vechiles      99.88
# Bumpy road      99.24
# No vechiles      99.96
# No vechiles      99.75
# No vechiles      99.99
# Yield      99.99
# No passing for vechiles over 3.5 metric tons      98.92
# Children crossing      99.54
# Right-of-way at the next intersection      98.05
# Speed Limit 30 km/h      99.88
# Speed Limit 120 km/h      98.72
# Yield      99.35
# Yield      99.26
# Ahead only      99.85
# Bicycles crossing      99.97
# Roundabout mandatory      99.97
# Roundabout mandatory      99.99
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Roundabout mandatory      99.97
# Roundabout mandatory      99.77
# Roundabout mandatory      100.0
# Roundabout mandatory      100.0
# Go straight or right      99.97
# Go straight or right      99.95
# Roundabout mandatory      99.87
# Dangerous curve to the right      99.96
# Roundabout mandatory      99.15
# Roundabout mandatory      98.7
# End of no passing      99.86
# Keep right      99.42
# Keep right      99.08
# Roundabout mandatory      99.53
# Roundabout mandatory      99.52
# Roundabout mandatory      99.82
# Roundabout mandatory      99.32
# No passing      99.69
# No passing      100.0
# No passing      100.0
# No passing      100.0
# No passing      99.67
# No passing      99.99
# No passing      99.98
# No passing      99.73
# Roundabout mandatory      99.17
# Roundabout mandatory      99.89
# Roundabout mandatory      99.35
# Roundabout mandatory      99.78
# Roundabout mandatory      99.37
# Roundabout mandatory      99.41
# No passing      98.64
# No passing      98.33
# No passing      100.0
# No passing      100.0
# No passing      100.0
# No passing      99.07
# No passing      99.99
# No passing      99.11
# Roundabout mandatory      98.68
# Roundabout mandatory      99.1
# Roundabout mandatory      99.85
# Roundabout mandatory      98.42
# Roundabout mandatory      98.69
# No passing      99.94
# No passing      99.99
# No passing      100.0
# No passing      100.0
# No passing      99.96
# No passing      99.96
# No passing      100.0
# No passing      100.0
# No passing      99.96
# Slippery road      99.69
# Slippery road      98.82
# Slippery road      98.99
# Slippery road      99.03
# Slippery road      99.99
# Slippery road      100.0
# Slippery road      99.96
# Slippery road      99.92
# Slippery road      99.95
# Slippery road      100.0
# Slippery road      100.0
# Slippery road      100.0
# Slippery road      99.73
# Slippery road      98.59
# Slippery road      99.37
# Slippery road      100.0
# Slippery road      100.0
# Slippery road      99.91
# No passing      100.0
# No passing      100.0
# No passing      99.99
# No passing      100.0
# No passing      100.0
# No passing      99.99
# No passing      99.99
# No passing      99.99
# No passing      99.97
# No passing      98.68
# Roundabout mandatory      99.49
# Roundabout mandatory      99.56
# Roundabout mandatory      99.38
# Roundabout mandatory      98.2
# Roundabout mandatory      99.97
# Roundabout mandatory      99.48
# No passing      100.0
# No passing      99.98
# No vechiles      98.76
# General caution      99.19
# Yield      99.38
# Yield      98.6
# Turn right ahead      98.17
# Yield      99.37
# Turn right ahead      99.77
# No vechiles      99.15
# Turn right ahead      99.55
# No vechiles      99.9
# Turn left ahead      99.99
# Yield      99.91
# Keep left      100.0
# General caution      99.96
# Yield      99.19
